# %% [markdown]
# <a href="https://colab.research.google.com/github/Nina-Racic/Repo_1/blob/main/Kod_prvi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = (2,3,4)

# %%
n
# Out:
# (2, 3, 4)
